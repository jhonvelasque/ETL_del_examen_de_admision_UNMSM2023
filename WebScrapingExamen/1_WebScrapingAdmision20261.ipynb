# %%
import pandas as pd
import requests
import lxml.html as html
import os
import datetime
import requests
from bs4 import BeautifulSoup
# Out:
# c:\Users\carlo\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#Teniendo la url para hacer el web scraping
##https://admision.unmsm.edu.pe/Website20261/index.html
urlModalidad='https://admision.unmsm.edu.pe/Website20261/index.html'

def get_modalidad_url(urlModalidad):
    response = requests.get(urlModalidad, headers={'Content-Type': 'text/html; charset=utf-8'})
    if response.status_code == 200:
    #traemos el contenido de la web 
        soup = BeautifulSoup(response.content.decode('utf-8'), 'html.parser')
        # estamos creando la url de todas las areas
        urls = [urlModalidad+a['href'][::] for a in soup.select('tbody tr td.text-center a')]
    return urls

# %%
#PROCESOS BASICOS DE BIUTIFUL

# %%
urlModalidad='https://admision.unmsm.edu.pe/Website20261/A/A.html'
response = requests.get(urlModalidad, headers={'Content-Type': 'text/html; charset=utf-8'})

# %%
soup = BeautifulSoup(response.content.decode('utf-8'), 'html.parser')

# %%
import requests
from bs4 import BeautifulSoup

# 1. Obtenemos el contenido de la web
url_base = "https://admision.unmsm.edu.pe/Website20261/A/A.html" # Cambia por la URL real
response = requests.get(url_base)

# 2. "Parseamos" el HTML
soup = BeautifulSoup(response.text, 'html.parser')

# 3. Buscamos los enlaces de las carreras
# Según la imagen, están dentro de una lista o tabla. 
# Buscamos todos los <a> que contengan texto de carreras
carreras = []

for link in soup.find_all('a'):
    nombre_carrera = link.text.strip()
    url_detalle = link.get('href')
    
    # Filtramos para solo traer lo que nos interesa
    #if "ADMINISTRACIÓN" in nombre_carrera or "ANTROPOLOGÍA" in nombre_carrera:
    carreras.append({
        "escuela": nombre_carrera,
        "link": url_detalle
    })

# Mostrar resultados
for c in carreras:
    print(f"Carrera: {c['escuela']} -> Link: {c['link']}")
# Out:
# Carrera: Inicio -> Link: ../index.html
# Carrera: ADMINISTRACIÃN - HUARAL -> Link: 0912/results.html
# Carrera: ADMINISTRACIÃN - LIMA -> Link: 091/results.html
# Carrera: ADMINISTRACIÃN - S.J.L -> Link: 0911/results.html
# Carrera: ADMINISTRACIÃN DE LA GASTRONOMÃA -> Link: 094/results.html
# Carrera: ADMINISTRACIÃN DE NEGOCIOS INTERNACIONALES - HUARAL -> Link: 0932/results.html
# Carrera: ADMINISTRACIÃN DE NEGOCIOS INTERNACIONALES - LIMA -> Link: 093/results.html
# Carrera: ADMINISTRACIÃN DE NEGOCIOS INTERNACIONALES - S.J.L -> Link: 0931/results.html
# Carrera: ADMINISTRACIÃN DE TURISMO - HUARAL -> Link: 0922/results.html
# Carrera: ADMINISTRACIÃN DE TURISMO - LIMA -> Link: 092/results.html
# Carrera: ADMINISTRACIÃN DE TURISMO - S.J.L -> Link: 0921/results.html
# Carrera: ADMINISTRACIÃN MARÃTIMA Y PORTUARIA -> Link: 095/results.html
# Carrera: ADMINISTRACION MARITIMA Y PORTUARIA - HUARAL -> Link: 0952/results.html
# Carrera: ANTROPOLOGÃA -> Link: 153/results.html
# Carrera: ARQUEOLOGÃA -> Link: 154/results.html
# Carrera: ARQUITECTURA Y URBANISMO -> Link: 169/results.html
# Carrera: ARTE -> Link: 036/results.html
# Carrera: AUDITORÃA EMPRESARIAL Y DEL SECTOR PÃBLICO - LIMA -> Link: 113/results.html
# Carrera: AUDITORÃA EMPRESARIAL Y DEL SECTOR PÃBLICO - S.J.L -> Link: 1131/results.html
# Carrera: BIBLIOTECOLOGÃA Y CIENCIAS DE LA INFORMACIÃN -> Link: 037/results.html
# Carrera: CIENCIA DE LA COMPUTACIÃN -> Link: 203/results.html
# Carrera: CIENCIA POLÃTICA -> Link: 023/results.html
# Carrera: CIENCIAS BIOLÃGICAS -> Link: 101/results.html
# Carrera: CIENCIAS DE LOS ALIMENTOS -> Link: 042/results.html
# Carrera: COMPUTACIÃN CIENTÃFICA -> Link: 145/results.html
# Carrera: COMUNICACIÃN SOCIAL -> Link: 035/results.html
# Carrera: CONSERVACIÃN Y RESTAURACIÃN -> Link: 039/results.html
# Carrera: CONTABILIDAD - HUARAL -> Link: 1112/results.html
# Carrera: CONTABILIDAD - LIMA -> Link: 111/results.html
# Carrera: CONTABILIDAD - S.J.L -> Link: 1111/results.html
# Carrera: CRIMINALÃSTICA FINANCIERA FORENSE -> Link: 115/results.html
# Carrera: DANZA -> Link: 038/results.html
# Carrera: DERECHO -> Link: 022/results.html
# Carrera: ECONOMÃA -> Link: 121/results.html
# Carrera: ECONOMÃA INTERNACIONAL -> Link: 123/results.html
# Carrera: ECONOMÃA PÃBLICA -> Link: 122/results.html
# Carrera: EDUCACIÃN FÃSICA -> Link: 062/results.html
# Carrera: EDUCACIÃN INICIAL -> Link: 0611/results.html
# Carrera: EDUCACIÃN PRIMARIA -> Link: 0612/results.html
# Carrera: EDUCACIÃN SECUNDARIA -> Link: 0613/results.html
# Carrera: ENFERMERÃA -> Link: 013/results.html
# Carrera: ESTADÃSTICA -> Link: 142/results.html
# Carrera: FARMACIA Y BIOQUÃMICA -> Link: 041/results.html
# Carrera: FILOSOFÃA -> Link: 033/results.html
# Carrera: FÃSICA -> Link: 131/results.html
# Carrera: GENÃTICA Y BIOTECNOLOGÃA -> Link: 102/results.html
# Carrera: GEOGRAFÃA -> Link: 157/results.html
# Carrera: GESTIÃN TRIBUTARIA - LIMA -> Link: 112/results.html
# Carrera: GESTIÃN TRIBUTARIA - S.J.L -> Link: 1121/results.html
# Carrera: HISTORIA -> Link: 151/results.html
# Carrera: INGENIERÃA AGROINDUSTRIAL -> Link: 073/results.html
# Carrera: INGENIERÃA AMBIENTAL -> Link: 168/results.html
# Carrera: INGENIERÃA BIOMÃDICA -> Link: 194/results.html
# Carrera: INGENIERÃA CIVIL -> Link: 167/results.html
# Carrera: INGENIERÃA DE MINAS -> Link: 165/results.html
# Carrera: INGENIERÃA DE SEGURIDAD Y SALUD EN EL TRABAJO -> Link: 173/results.html
# Carrera: INGENIERÃA DE SISTEMAS -> Link: 201/results.html
# Carrera: INGENIERÃA DE SOFTWARE -> Link: 202/results.html
# Carrera: INGENIERÃA DE TELECOMUNICACIONES -> Link: 193/results.html
# Carrera: INGENIERIA DEL AGUA Y TECNOLOGIAS DE TRATAMIENTO -> Link: 074/results.html
# Carrera: INGENIERÃA ELÃCTRICA -> Link: 192/results.html
# Carrera: INGENIERÃA ELECTRÃNICA -> Link: 191/results.html
# Carrera: INGENIERÃA GEOGRÃFICA -> Link: 163/results.html
# Carrera: INGENIERÃA GEOLÃGICA -> Link: 162/results.html
# Carrera: INGENIERÃA INDUSTRIAL -> Link: 171/results.html
# Carrera: INGENIERÃA LOGÃSTICA Y CADENA DE SUMISTRO DIGITAL -> Link: 174/results.html
# Carrera: INGENIERÃA MECÃNICA DE FLUIDOS -> Link: 132/results.html
# Carrera: INGENIERÃA MECATRONICA -> Link: 195/results.html
# Carrera: INGENIERÃA METALÃRGICA -> Link: 166/results.html
# Carrera: INGENIERÃA NUCLEAR -> Link: 196/results.html
# Carrera: INGENIERÃA QUÃMICA -> Link: 072/results.html
# Carrera: INGENIERÃA TEXTIL Y CONFECCIONES -> Link: 172/results.html
# Carrera: INVESTIGACIÃN OPERATIVA -> Link: 144/results.html
# Carrera: LENGUAS, TRADUCCIÃN E INTERPRETACIÃN -> Link: 0310/results.html
# Carrera: LINGUÃSTICA -> Link: 034/results.html
# Carrera: LITERATURA -> Link: 031/results.html
# Carrera: MARKETING -> Link: 096/results.html
# Carrera: MATEMÃTICA -> Link: 141/results.html
# Carrera: MEDICINA HUMANA -> Link: 011/results.html
# Carrera: MEDICINA VETERINARIA -> Link: 081/results.html
# Carrera: MICROBIOLOGÃA Y PARASITOLOGÃA -> Link: 103/results.html
# Carrera: NUTRICION -> Link: 015/results.html
# Carrera: OBSTETRICIA -> Link: 012/results.html
# Carrera: ODONTOLOGÃA -> Link: 051/results.html
# Carrera: PRESUPUESTO Y FINANZAS PÃBLICAS - LIMA -> Link: 114/results.html
# Carrera: PRESUPUESTO Y FINANZAS PÃBLICAS - S.J.L -> Link: 1141/results.html
# Carrera: PSICOLOGÃA -> Link: 181/results.html
# Carrera: PSICOLOGÃA ORGANIZACIONAL Y DE LA GESTIÃN HUMANA -> Link: 182/results.html
# Carrera: QUÃMICA -> Link: 071/results.html
# Carrera: SOCIOLOGÃA -> Link: 152/results.html
# Carrera: TEC. MED. LAB. CLÃNICO Y ANATOMÃA PATOLÃGICA -> Link: 0141/results.html
# Carrera: TEC. MED. RADIOLOGÃA -> Link: 0143/results.html
# Carrera: TEC. MED. TERAPIA FÃSICA Y REHABILITACIÃN -> Link: 0142/results.html
# Carrera: TEC. MED. TERAPIA OCUPACIONAL -> Link: 0144/results.html
# Carrera: TOXICOLOGÃA -> Link: 043/results.html
# Carrera: TRABAJO SOCIAL -> Link: 155/results.html

# %%
def tabla_modalidad(urlModalidad):
    response = requests.get(urlModalidad, headers={'Content-Type': 'text/html; charset=utf-8'})
    if response.status_code == 200:
    #traemos el contenido de la web 
        soup = BeautifulSoup(response.content.decode('utf-8'), 'html.parser')
        # estamos creando la url de todas las areas
        contents = [a.text.lower() for a in soup.select('tbody tr td.text-center a')]
        tabla =pd.DataFrame(contents,columns=['Modalidad']).reset_index()
        tabla.rename(columns={'index': 'id_modalidad'},inplace=True)
    return tabla

# %%
#creando la tabla de modalidades
tabla_modalidad=tabla_modalidad(urlModalidad)

# %%
# Out:
# Empty DataFrame
# Columns: [id_modalidad, Modalidad]
# Index: []

# %%
#Exportando las modalidades de Ingreso 
tabla_modalidad.to_csv('./data/tabla_modalidad.csv',index=False,sep=',')

# %%
#creando la funcion para obtener la los links de cada carrera por modaldidad 
def get_carrera_url(urlAdmision):
    response = requests.get(urlAdmision, headers={'Content-Type': 'text/html; charset=utf-8'})
    if response.status_code == 200:
    #traemos el contenido de la web 
        soup = BeautifulSoup(response.content.decode('utf-8'), 'html.parser')
        # estamos creando la url de todas las areas
        urls = [urlAdmision[:-7:]+a['href'][1::] for a in soup.select('tbody tr td.text-center a')]
        return urls

# %%
def tabla_carrera(urlAdmision):
    response = requests.get(urlAdmision, headers={'Content-Type': 'text/html; charset=utf-8'})
    if response.status_code == 200:
    #traemos el contenido de la web 
        soup = BeautifulSoup(response.content.decode('utf-8'), 'html.parser')
        # estamos creando la url de todas las areas
        tabla = [[a['href'][4:-7:],a.text.upper()] for a in soup.select('tbody tr td.text-center a')]
        tabla=pd.DataFrame(tabla,columns=['IdCarrera','Carrera'])
        return tabla

# %%
tabla_carrera=tabla_carrera('https://admision.unmsm.edu.pe/Website20261/A/A.html')
tabla_carrera.IdCarrera=tabla_carrera.IdCarrera.astype(int)

# %%
#exportando nuestra tabla de carreras 
tabla_carrera.to_csv('./data/tabla_carrera.csv',sep=',',index=False)

# %%
df=pd.read_html('https://admision.unmsm.edu.pe/Website20261/A/A.html')

# %%
for i in df:
    print(i.head(2
                 ))
# Out:
#                          0
# 0  ADMINISTRACIÓN - HUARAL
# 1    ADMINISTRACIÓN - LIMA

# %%
df[df.index==912]
# Out:
# Empty DataFrame
# Columns: [index, 0]
# Index: []

# %%
## https://admision.unmsm.edu.pe/Website20261/A/0912/results.html

# %%
url='https://admision.unmsm.edu.pe/WebsiteExa_20232/'

urlsModalidad=get_modalidad_url(url)

# %%
tabla_modalidad
# Out:
#     id_modalidad                                          Modalidad
# 0              0  educación básica regular (ebr) y educación bás...
# 1              1           primeros puestos de educación secundaria
# 2              2                                   traslado interno
# 3              3                              graduados o titulados
# 4              4                          traslado externo nacional
# 5              5                     traslado externo internacional
# 6              6                              deportista calificado
# 7              7              deportistas calificados de alto nivel
# 8              8                                comunidades nativas
# 9              9                          personas con discapacidad
# 10            10                      plan integral de reparaciones

# %%
#en esta funcion se introduce una lista
#devuelve el dataframe de todas las carreraspor modalidad y con id modaldiad
def get_df(urls,num):
    resultados = pd.DataFrame()
    for url in urls:
        tables = pd.read_html(url, encoding='utf-8')
        table = pd.concat(tables)
        resultados = pd.concat([resultados, table], ignore_index=True)
    resultados['IdModalidad']=num
    return resultados

# %%
#recolectamos todas las url opr modalidad de ingreso
urlsModalidad=get_modalidad_url(url)
urlsCarrera=[]
for i , urlModalidad in enumerate(urlsModalidad):
    #guardando las url de carrera
    urlsCarrera.append(get_carrera_url(urlModalidad))

# %%
#probando la funcion
resultados=get_df(urlsCarrera[4],2)
resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CODIGO               84 non-null     int64
#  1   APELLIDOS Y NOMBRES  84 non-null     object
#  2   ESCUELA PROFESIONAL  84 non-null     object
#  3   PUNTAJE FINAL        84 non-null     object
#  4   MERITO E.P           19 non-null     float64
#  5   OBSERVACI&OacuteN    41 non-null     object
#  6   IdModalidad          84 non-null     int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 4.7+ KB

# %%
resultados['PUNTAJE FINAL'].unique()
# Out:
# array([958.625, 721.75, 951.875, 913.0, 966.25, 670.5, 831.875, 1008.5,
#        546.0, 564.875, 551.625, 680.625, 755.0, 802.875, 869.625, 743.125,
#        820.875, 438.625, 468.5, 343.75, 'Art. 71º Reglamento', 566.0,
#        776.125, 397.0, 600.625, 416.125, 871.875, 720.625, 311.375, 599.5,
#        99.5, 605.375, 735.0, 543.75, 558.375, 651.625, 353.875, 254.75,
#        361.75, 573.0, 567.125, 804.25, 576.375, 161.75, 536.375, 518.375,
#        480.375, 438.125, 199.75, 712.75, 691.625, 649.375, 290.5, 510.75,
#        452.75, 410.75, 423.75, 902.875, 384.875], dtype=object)

# %%
resultados['PUNTAJE FINAL']=='Art. 71º Reglamento'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 79     True
# 80     True
# 81     True
# 82    False
# 83    False
# Name: PUNTAJE FINAL, Length: 84, dtype: bool

# %%
#creando un bucle para extraer la informacion de todos los postulantes ausentes y que ingresaron
todo = pd.DataFrame()
for i in range(len(urlsCarrera)):
    resultado=get_df(urlsCarrera[i],i)
    todo = pd.concat([todo, resultado], ignore_index=True)

# %%
#exportamdo los resultados de examen de admision 
#hacer un for donde extraigamos toda la data y le incluya una columna para especificar su modalidad
todo.to_csv('./data/tabla_resultados.csv',index=False,sep=',')

# %%
todo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25832 entries, 0 to 25831
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CODIGO               25832 non-null  int64
#  1   APELLIDOS Y NOMBRES  25832 non-null  object
#  2   ESCUELA PROFESIONAL  25832 non-null  object
#  3   PUNTAJE FINAL        25352 non-null  object
#  4   MERITO E.P           4079 non-null   float64
#  5   OBSERVACI&OacuteN    4740 non-null   object
#  6   IdModalidad          25832 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.4+ MB
